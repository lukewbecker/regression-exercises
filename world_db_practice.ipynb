# %% [markdown]
# # World Data Mini-Project Notebook
#
# Exploratory work and Analysis will be performed in this notebook, up to any modeling that needs to be accomplished.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from math import sqrt
from scipy import stats

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,recall_score,precision_score

import os

import warnings
warnings.filterwarnings("ignore")

# %%
from env import host, user, password

# %%
# world db all query:
world_all = '''
            SELECT c.*, cy.Name, cy.District, cy.Population, cl.Language, cl.Isofficial, cl.Percentage
            FROM country as c
            JOIN city AS cy ON c.code = cy.countrycode
            JOIN countrylanguage as cl ON c.code = cl.countrycode;
            '''

# %%
def get_db(db, user=user, host=host, password=password):
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

# %%
def new_world_data():
    
    '''
    This function reads the world data from the Codeup db into a df,
    writes it to a csv file, and returns the df.
    '''
    
    world_all = '''
                SELECT c.*, cy.Name, cy.District, cy.Population, cl.Language, cl.Isofficial, cl.Percentage
                FROM country as c
                JOIN city AS cy ON c.code = cy.countrycode
                JOIN countrylanguage as cl ON c.code = cl.countrycode;
                '''

# %%
def get_world_data(cache = False):
    
    world_all = '''
            SELECT c.*, cy.Name, cy.District, cy.Population, cl.Language, cl.Isofficial, cl.Percentage
            FROM country as c
            JOIN city AS cy ON c.code = cy.countrycode
            JOIN countrylanguage as cl ON c.code = cl.countrycode;
            '''
    
    
    filename = 'world_data.csv'
    
    if os.path.isfile(filename):
        return pd.read_csv(filename)
    else:
        df = pd.read_sql(world_all, get_db('world'))
        df.to_csv(filename, index = False)
        
    return df

# %%
df = get_world_data()
df
# Out:
#       Code         Name      Continent                     Region  \
# 0      ABW        Aruba  North America                  Caribbean
# 1      ABW        Aruba  North America                  Caribbean
# 2      ABW        Aruba  North America                  Caribbean
# 3      ABW        Aruba  North America                  Caribbean
# 4      AFG  Afghanistan           Asia  Southern and Central Asia
# ...    ...          ...            ...                        ...
# 30665  ZWE     Zimbabwe         Africa             Eastern Africa
# 30666  ZWE     Zimbabwe         Africa             Eastern Africa
# 30667  ZWE     Zimbabwe         Africa             Eastern Africa
# 30668  ZWE     Zimbabwe         Africa             Eastern Africa
# 30669  ZWE     Zimbabwe         Africa             Eastern Africa
#
#        SurfaceArea  IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0            193.0        NaN      103000            78.4   828.0   793.0
# 1            193.0        NaN      103000            78.4   828.0   793.0
# 2            193.0        NaN      103000            78.4   828.0   793.0
# 3            193.0        NaN      103000            78.4   828.0   793.0
# 4         652090.0     1919.0    22720000            45.9  5976.0     NaN
# ...            ...        ...         ...             ...     ...     ...
# 30665     390757.0     1980.0    11669000            37.8  5951.0  8670.0
# 30666     390757.0     1980.0    11669000            37.8  5951.0  8670.0
# 30667     390757.0     1980.0    11669000            37.8  5951.0  8670.0
# 30668     390757.0     1980.0    11669000            37.8  5951.0  8670.0
# 30669     390757.0     1980.0    11669000            37.8  5951.0  8670.0
#
#        ...                                GovernmentForm       HeadOfState  \
# 0      ...  Nonmetropolitan Territory of The Netherlands           Beatrix
# 1      ...  Nonmetropolitan Territory of The Netherlands           Beatrix
# 2      ...  Nonmetropolitan Territory of The Netherlands           Beatrix
# 3      ...  Nonmetropolitan Territory of The Netherlands           Beatrix
# 4      ...                               Islamic Emirate     Mohammad Omar
# ...    ...                                           ...               ...
# 30665  ...                                      Republic  Robert G. Mugabe
# 30666  ...                                      Republic  Robert G. Mugabe
# 30667  ...                                      Republic  Robert G. Mugabe
# 30668  ...                                      Republic  Robert G. Mugabe
# 30669  ...                                      Republic  Robert G. Mugabe
#
#       Capital  Code2      Name.1    District Population.1    Language  \
# 0         129     AW  Oranjestad           –        29034       Dutch
# 1         129     AW  Oranjestad           –        29034     English
# 2         129     AW  Oranjestad           –        29034  Papiamento
# 3         129     AW  Oranjestad           –        29034     Spanish
# 4           1     AF       Kabul       Kabol      1780000     Balochi
# ...       ...    ...         ...         ...          ...         ...
# 30665    4068     ZW      Mutare  Manicaland       131367       Shona
# 30666    4068     ZW       Gweru    Midlands       128037     English
# 30667    4068     ZW       Gweru    Midlands       128037     Ndebele
# 30668    4068     ZW       Gweru    Midlands       128037      Nyanja
# 30669    4068     ZW       Gweru    Midlands       128037       Shona
#
#       Isofficial Percentage
# 0              T        5.3
# 1              F        9.5
# 2              F       76.7
# 3              F        7.4
# 4              F        0.9
# ...          ...        ...
# 30665          F       72.1
# 30666          T        2.2
# 30667          F       16.2
# 30668          F        2.2
# 30669          F       72.1
#
# [30670 rows x 21 columns]

# %%
df['Name.1'].value_counts()
# Out:
# Richmond       36
# Springfield    36
# San Jose       32
# Toledo         27
# Cambridge      27
#                ..
# Tabuk           1
# al-Mubarraz     1
# Bayamo          1
# al-Kharj        1
# Montevideo      1
# Name: Name.1, Length: 4001, dtype: int64

# %% [markdown]
# ## Prep/Tidy Data
#
# Needs a lot of prep and cleanup, starting with Column Renaiming.
